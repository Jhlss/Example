# %%
using IntervalArithmetic

# %%
using Plots

# %%
using RigorousInvariantMeasures
# Out:
# ┌ Info: Precompiling RigorousInvariantMeasures [6103b61f-200f-420b-b397-2cbeef157920]
# └ @ Base loading.jl:1664

# %%
Λ = Interval(3)
α = Λ/(Λ-1)
# Out:
# [1.5, 1.5]

# %%
K = Int64(floor(mid(Λ)))
# Out:
# 3

# %%
using Pkg

# %%
Pkg.add("Symbolics")
# Out:
#     Updating registry at `~/.julia/registries/General.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.8/Project.toml`
#   No Changes to `~/.julia/environments/v1.8/Manifest.toml`

# %%
using Symbolics

# %%
g(x)=mod(x + α*(1-(1^2-(1/α)*(1+1-2*x))^(0.5)),1)
# Out:
# g (generic function with 1 method)

# %%
df2(x)=(1-(1/(1-6/9*(2-2*x))^(0.5))*(1-(1-6/9*(2-2*(1.5*(1-(1-6/9*(2-2*x))^(0.5))+x-1))))^(0.5))-1
# Out:
# df2 (generic function with 1 method)

# %%
gndf2(x)=1/(((df2(x))^2)^(0.5))
# Out:
# gndf2 (generic function with 1 method)

# %%
plot(x->mid(df2(x)), 0.383974, 0.383975)

# %%
plot(x->mid(gndf2(x)), 0.383974, 0.383975)

# %%
gndf2(0.383974)
# Out:
# 0.4226490198521469

# %%
plot(x->mid(g(x)), 0, 1)
# Out:
# mod not defined for Interval{Float64}
#
# Stacktrace:
#   [1] error(::String, ::String, ::Type)
#     @ Base ./error.jl:44
#   [2] no_op_err(name::String, T::Type)
#     @ Base ./promotion.jl:462
#   [3] mod(x::Interval{Float64}, y::Interval{Float64})
#     @ Base ./promotion.jl:482
#   [4] mod(x::Interval{Float64}, y::Int64)
#     @ Base ./promotion.jl:432
#   [5] g(x::Float64)
#     @ Main ./In[9]:1
#   [6] (::var"#21#22")(x::Float64)
#     @ Main ./In[30]:1
#   [7] call_composed
#     @ ./operators.jl:1039 [inlined]
#   [8] (::ComposedFunction{ComposedFunction{RecipesPipeline.var"#1#2"{Symbol}, var"#21#22"}, RecipesPipeline.var"#3#4"{Symbol}})(x::Float64; kw::Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}})
#     @ Base ./operators.jl:1035
#   [9] ComposedFunction
#     @ ./operators.jl:1033 [inlined]
#  [10] (::PlotUtils.var"#27#29"{ComposedFunction{ComposedFunction{RecipesPipeline.var"#1#2"{Symbol}, var"#21#22"}, RecipesPipeline.var"#3#4"{Symbol}}})(x::Float64)
# ...
